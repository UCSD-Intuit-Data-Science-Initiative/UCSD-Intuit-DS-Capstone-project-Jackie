# %% [markdown]
# # Workforce Optimization with Erlang-C
#
# ## What This Notebook Does
# Given call center demand, this notebook finds the **minimum number of agents needed** to meet service level targets.
#
# **Problem:** 317 calls/day, 95 sec handle time → How many agents do I need?
# **Answer:** Use Erlang-C + Optimization to find optimal staffing
#
# ## Notebook Structure
# 1. **Erlang-C Implementation** - Calculate wait times and occupancy
# 2. **Optimization Functions** - Find minimum agents (2 approaches)
# 3. **Example** - Test on real data
# 4. **Batch Processing** - Apply to entire dataset

# %%
import math
from dataclasses import dataclass

@dataclass
class ErlangCResult:
    prob_wait: float   # P(wait > 0)
    asa: float         # Average Speed of Answer (seconds)
    occupancy: float   # Utilization (0-1)


def erlang_c(N: int, arrival_rate: float, aht: float) -> ErlangCResult:
    """
    Compute Erlang-C performance metrics.

    Parameters
    ----------
    N : int
        Number of agents (servers).
    arrival_rate : float
        Arrival rate λ (calls per second).
    aht : float
        Average handle time H (seconds).

    Returns
    -------
    ErlangCResult
        prob_wait: P(call has to wait)
        asa: Average speed of answer (seconds)
        occupancy: Agent occupancy (0-1)
    """
    if N <= 0:
        raise ValueError("N must be positive.")

    # Offered load in Erlangs: a = λ * H
    a = arrival_rate * aht

    # If offered load >= agents, system is unstable → infinite queue
    if a >= N:
        return ErlangCResult(
            prob_wait=1.0,
            asa=float("inf"),
            occupancy=1.0
        )

    # Denominator sum: sum_{k=0}^{N-1} a^k / k!
    denom_sum = 0.0
    for k in range(N):
        denom_sum += a**k / math.factorial(k)

    # "Last term" with queue correction: (a^N / N!) * (N / (N - a))
    last_term = (a**N / math.factorial(N)) * (N / (N - a))

    # Probability that all agents are busy (Erlang C wait probability)
    prob_wait = last_term / (denom_sum + last_term)

    # Average waiting time in queue (Wq)
    # Wq = Pw * H / (N - a)
    asa = (prob_wait * aht) / (N - a)

    # Occupancy = a / N
    occupancy = a / N

    return ErlangCResult(
        prob_wait=prob_wait,
        asa=asa,
        occupancy=occupancy
    )

# %%
import numpy as np
from scipy.optimize import minimize_scalar, minimize
import pandas as pd

# ============================================================================
# APPROACH 1: SIMPLE SEARCH - Minimize Headcount with ASA Constraint
### Return the first N that fultill the asa ti
# ============================================================================

def find_minimum_agents_simple(arrival_rate: float, 
                                 aht: float, 
                                 target_asa: float,
                                 max_occupancy: float = 0.85) -> dict:
    """
    Find minimum number of agents using simple search.
    
    This is the easiest approach: try N=1, 2, 3, ... until constraints are met.
    
    Parameters
    ----------
    arrival_rate : float
        Calls per second (e.g., 500 calls / 1800 seconds = 0.278)
    aht : float
        Average handle time in seconds
    target_asa : float
        Target average speed of answer in seconds (e.g., 20)
    max_occupancy : float
        Maximum allowed occupancy (e.g., 0.85 = 85%)
    
    Returns
    -------
    dict with keys: optimal_agents, asa, occupancy, feasible
    """
    # Minimum agents needed for stability: offered_load / max_occupancy
    offered_load = arrival_rate * aht
    min_agents = int(np.ceil(offered_load / max_occupancy))
    
    # Search from min_agents upward
    for N in range(min_agents, min_agents + 100):
        result = erlang_c(N, arrival_rate, aht)
        
        # Check if both constraints are satisfied
        if result.asa <= target_asa and result.occupancy <= max_occupancy:
            return {
                'optimal_agents': N,
                'asa': result.asa,
                'occupancy': result.occupancy,
                'prob_wait': result.prob_wait,
                'feasible': True
            }
    
    return {
        'optimal_agents': None,
        'asa': None,
        'occupancy': None,
        'prob_wait': None,
        'feasible': False
    }

# %%
# Test Approach 1: Simple Search
print("\n" + "="*70)
print("APPROACH 1: SIMPLE SEARCH")
print("="*70)

result1 = find_minimum_agents_simple(
    arrival_rate=arrival_rate,
    aht=aht,
    target_asa=target_asa,
    max_occupancy=max_occupancy
)

print(f"Optimal Agents: {result1['optimal_agents']}")
print(f"Resulting ASA: {result1['asa']:.2f} seconds (target: ≤{target_asa})")
print(f"Resulting Occupancy: {result1['occupancy']*100:.1f}% (target: ≤{max_occupancy*100}%)")
print(f"Probability of Wait: {result1['prob_wait']*100:.1f}%")
print(f"Feasible: {result1['feasible']}")
# Out:
# ...
# APPROACH 1: SIMPLE SEARCH
# ...
# Optimal Agents: 3
# Resulting ASA: 4.93 seconds (target: ≤20.0)
# Resulting Occupancy: 34.9% (target: ≤85.0%)
# Probability of Wait: 10.1%
# Feasible: True

# %%
# ============================================================================
# APPROACH 2: SCIPY MINIMIZE with Constraints (Nonlinear Optimization)
# ============================================================================

def find_minimum_agents_scipy(arrival_rate: float,
                                aht: float,
                                target_asa: float,
                                max_occupancy: float = 0.85,
                                cost_per_agent: float = 1.0) -> dict:
    """
    Find minimum number of agents using scipy.optimize.minimize.
    
    This demonstrates how to set up a constrained optimization problem
    where the objective is to minimize cost (or headcount) subject to
    service level and occupancy constraints.
    
    Parameters
    ----------
    arrival_rate : float
        Calls per second
    aht : float
        Average handle time in seconds
    target_asa : float
        Maximum allowable ASA in seconds
    max_occupancy : float
        Maximum allowable occupancy (0-1)
    cost_per_agent : float
        Cost per agent (for cost minimization)
    
    Returns
    -------
    dict with optimization results
    """
    offered_load = arrival_rate * aht
    
    # Objective function: minimize cost = cost_per_agent * N
    def objective(N):
        return cost_per_agent * N[0]
    
    # Constraint 1: ASA <= target_asa
    # Written as: target_asa - ASA(N) >= 0
    def constraint_asa(N):
        N_int = int(np.round(N[0]))
        if N_int < 1:
            return -1e10  # Infeasible
        result = erlang_c(N_int, arrival_rate, aht)
        return target_asa - result.asa
    
    # Constraint 2: occupancy <= max_occupancy
    # Written as: max_occupancy - occupancy(N) >= 0
    def constraint_occupancy(N):
        N_int = int(np.round(N[0]))
        if N_int < 1:
            return -1e10
        result = erlang_c(N_int, arrival_rate, aht)
        return max_occupancy - result.occupancy
    
    # Initial guess: minimum agents for stability
    N0 = max(1, int(np.ceil(offered_load / max_occupancy)))
    
    # Bounds: N must be at least 1 and at most some reasonable upper bound
    bounds = [(N0, N0 + 100)]
    
    # Constraints in scipy format
    constraints = [
        {'type': 'ineq', 'fun': constraint_asa},
        {'type': 'ineq', 'fun': constraint_occupancy}
    ]
    
    # Solve
    result_opt = minimize(
        objective,
        x0=[N0],
        method='SLSQP',  # Sequential Least Squares Programming
        bounds=bounds,
        constraints=constraints,
        options={'ftol': 1e-6}
    )
    
    # Extract optimal solution
    N_optimal = int(np.round(result_opt.x[0]))
    final_result = erlang_c(N_optimal, arrival_rate, aht)
    
    return {
        'optimal_agents': N_optimal,
        'asa': final_result.asa,
        'occupancy': final_result.occupancy,
        'prob_wait': final_result.prob_wait,
        'cost': cost_per_agent * N_optimal,
        'success': result_opt.success,
        'message': result_opt.message
    }

# %%
def optimize_staffing_for_dataset(df: pd.DataFrame, 
                                   work_hours: int = 8,
                                   target_asa: float = 20.0,
                                   max_occupancy: float = 0.85) -> pd.DataFrame:
    """
    Apply workforce optimization to entire dataset.
    
    Parameters
    ----------
    df : pd.DataFrame
        Call center data with columns: Date, Incoming Calls, Talk Duration (AVG)
    work_hours : int
        Hours of operation per day
    target_asa : float
        Target ASA in seconds
    max_occupancy : float
        Maximum occupancy
    
    Returns
    -------
    pd.DataFrame with optimization results
    """
    results = []
    
    for idx, row in df.iterrows():
        work_seconds = work_hours * 3600
        arrival_rate = row['Incoming Calls'] / work_seconds
        aht = row['Talk Duration (AVG)']
        
        # Skip if data is missing
        if pd.isna(aht) or aht <= 0:
            continue
        
        # Find optimal staffing
        opt = find_minimum_agents_simple(
            arrival_rate=arrival_rate,
            aht=aht,
            target_asa=target_asa,
            max_occupancy=max_occupancy
        )
        
        results.append({
            'Date': row['Date'],
            'Incoming_Calls': row['Incoming Calls'],
            'AHT_seconds': aht,
            'Arrival_Rate': arrival_rate,
            'Offered_Load': arrival_rate * aht,
            'Optimal_Agents': opt['optimal_agents'],
            'Predicted_ASA': opt['asa'],
            'Predicted_Occupancy': opt['occupancy'],
            'Prob_Wait': opt['prob_wait'],
            'Feasible': opt['feasible']
        })
    
    return pd.DataFrame(results)

# Process first 100 days as example
df_sample = df.head(100)
staffing_results = optimize_staffing_for_dataset(
    df_sample,
    work_hours=8,
    target_asa=20.0,
    max_occupancy=0.85
)

print(f"Processed {len(staffing_results)} days")
print("\nSample Results:")
staffing_results.head(10)
# Out:
# Processed 100 days
#
# Sample Results:
#          Date  Incoming_Calls  AHT_seconds  Arrival_Rate  Offered_Load  \
# 0  2022-01-01             157        149.0      0.005451      0.812257
# 1  2022-01-02              37        126.0      0.001285      0.161875
# 2  2022-01-03             317         95.0      0.011007      1.045660
# 3  2022-01-04             253        110.0      0.008785      0.966319
# 4  2022-01-05             214        130.0      0.007431      0.965972
# 5  2022-01-06             222        138.0      0.007708      1.063750
# 6  2022-01-07             375        100.0      0.013021      1.302083
# 7  2022-01-08             166        130.0      0.005764      0.749306
# 8  2022-01-09              32        123.0      0.001111      0.136667
# 9  2022-01-10             232        109.0      0.008056      0.878056
#
#    Optimal_Agents  Predicted_ASA  Predicted_Occupancy  Prob_Wait  Feasible
# ...

# %%
# Summary statistics
print("\n" + "="*70)
print("STAFFING OPTIMIZATION SUMMARY")
print("="*70)
print(f"Total Days Analyzed: {len(staffing_results)}")
print(f"Average Optimal Agents: {staffing_results['Optimal_Agents'].mean():.1f}")
print(f"Min Agents Needed: {staffing_results['Optimal_Agents'].min()}")
print(f"Max Agents Needed: {staffing_results['Optimal_Agents'].max()}")
print(f"Median Agents Needed: {staffing_results['Optimal_Agents'].median():.0f}")
print()
print(f"Average Predicted ASA: {staffing_results['Predicted_ASA'].mean():.2f} seconds")
print(f"Average Predicted Occupancy: {staffing_results['Predicted_Occupancy'].mean()*100:.1f}%")
print(f"Average Prob(Wait): {staffing_results['Prob_Wait'].mean()*100:.1f}%")
print()
print(f"Days where optimization was feasible: {staffing_results['Feasible'].sum()} / {len(staffing_results)}")
print("="*70)
# Out:
# ...
# STAFFING OPTIMIZATION SUMMARY
# ...
# Total Days Analyzed: 100
# Average Optimal Agents: 2.7
# Min Agents Needed: 1
# Max Agents Needed: 4
# Median Agents Needed: 3
#
# Average Predicted ASA: 6.48 seconds
# Average Predicted Occupancy: 27.8%
# Average Prob(Wait): 8.3%
#
# Days where optimization was feasible: 100 / 100
# ...
